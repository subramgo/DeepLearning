# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

images = glob.glob('../data/Adience/gender/train/female/*.jpg')


count = 1
for im in images:
    img = cv2.imread(im)
    h, w = img[:2]
    print (img.shape)
    count+=1
    plt.figure(count)
    plt.imshow(img)


    if count == 5:
        break
# Out:
# (600, 601, 3)
# (600, 600, 3)
# (600, 600, 3)
# (497, 497, 3)

# %%
resized_image = cv2.resize(img, (64, 64)) 
plt.imshow(resized_image, shape= (64,64))
print(resized_image.shape)
# Out:
# (64, 64, 3)
